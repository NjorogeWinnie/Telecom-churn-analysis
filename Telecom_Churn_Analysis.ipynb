# %% [markdown]
# <a href="https://colab.research.google.com/github/NjorogeWinnie/Telecom-churn-analysis/blob/main/Telecom_Churn_Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %cd /content/
# !ls -a
# Out:
# /content
# .  ..  .config	sample_data  Telecom-churn-analysis

# %%
# Ensure we are in the root directory
# %cd /content/

# 1. Clean up and re-clone
# !rm -rf Telecom-churn-analysis
# !git clone https://github.com/NjorogeWinnie/Telecom-churn-analysis.git

# 2. Move into the repo
# %cd Telecom-churn-analysis

# 3. SET IDENTITY AGAIN (inside the repo directory)
# !git config user.name "NjorogeWinnie"
# !git config user.email "muthoniwinnie573@gmail.com"

# 4. Move the file (The crucial step)
# *** REPLACE 'YOUR_ACTUAL_NOTEBOOK_NAME.ipynb' WITH THE NAME FOUND IN STEP 1 ***
# !mv /content/Telecom\Churn\Analysis/.ipynb .

# 5. Stage and Commit
# !git add .
# !git commit -m "Final push after fixing all config issues"

# 6. PUSH using the PAT (Replace YOUR_PAT_TOKEN)
# This is the command that guarantees authentication:
# !git push https://NjorogeWinnie:ghp_WnSBr7tjWVZrQFtxIOftQwDVxRxrWq1l@github.com/NjorogeWinnie/Telecom-churn-analysis.git
# Out:
# /content
# Cloning into 'Telecom-churn-analysis'...
# remote: Enumerating objects: 4, done.
# remote: Counting objects: 100% (4/4), done.
# remote: Compressing objects: 100% (4/4), done.
# remote: Total 4 (delta 0), reused 0 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (4/4), done.
# /content/Telecom-churn-analysis
# mv: cannot stat '/content/TelecomChurnAnalysis/.ipynb': No such file or directory
# On branch main
# Your branch is up to date with 'origin/main'.
#
# nothing to commit, working tree clean
# remote: Invalid username or token. Password authentication is not supported for Git operations.
# fatal: Authentication failed for 'https://github.com/NjorogeWinnie/Telecom-churn-analysis.git/'

# %% [markdown]
# ## **Business Understanding**
#
# ### Business Problem
# SyriaTel loses revenue due to customer churn and this is a significant challenge as acquaring new customers is more expensive than retaining existing ones. A data driven approach is thus needed to identify customers at high risk of churning so that retention strategies are applied more effectively.
#
# ### Objectives
# - Primary Objective.
#
# Develop a classification model that maximizes recall to help identify the number of customers who leave without prior knowledge.
# - Secondary Objective
#
# 1. Identify key features associated with customer churn to inform retention strategies.
# 2. Compare multiple classification models to evaluate
